# %%
import plotly.graph_objects as go
import pandas as pd
car_data = csv_read = pd.read_csv('C:\\Users\\Oscar\\Documents\\sprint7_proj\\vehicles_us.csv')
fig = go.Figure(data=[go.Histogram(x=car_data['odometer'])])
fig.update_layout(title='Histogram of Odometer Readings',
                  xaxis_title='Odometer Reading')
fig.show()
